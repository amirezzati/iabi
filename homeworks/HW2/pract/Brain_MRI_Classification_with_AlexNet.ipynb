# %% [markdown]
# <div dir=ltr align=center>In the name of God</div>
# <br>
# <font size=6><div dir=ltr align=center>
# <font size=5>
# Intelligent Analysis of
# Biomedical Images
# <br>
# <font size=4>
# Sharif University of Technology, CE department
# </font>
# <br>
# <br>
# <font size=6>
# Homework 2
# </font><br>
# <font size=4>
# AlexNet - MRI Classification
# </font>

# %% [markdown]
# **First-Name: Amir Mohammad**
#
# **Last-Name: Ezzati**
#
# **Student-Id: 402212269**

# %% [markdown]
# ## Import libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
data_path = "/content/drive/MyDrive/SPB/HW2/data/"
# Out:
# Mounted at /content/drive

# %%
# !pip install wandb
# Out:
# Collecting wandb
#   Downloading wandb-0.15.12-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.7)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb)
#   Downloading GitPython-3.1.40-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 12.4 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (5.9.5)
# Collecting sentry-sdk>=1.0.0 (from wandb)
#   Downloading sentry_sdk-1.34.0-py2.py3-none-any.whl (243 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.9/243.9 kB 13.8 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from wandb) (6.0.1)
# Collecting pathtools (from wandb)
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting setproctitle (from wandb)
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2023.7.22)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=104fc448e907203f6a88f5e798baf8f01c70381c239c539bc834d641495f4f2d
#   Stored in directory: /root/.cache/pip/wheels/e7/f3/22/152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
# Successfully built pathtools
# Installing collected packages: pathtools, smmap, setproctitle, sentry-sdk, docker-pycreds, gitdb, GitPython, wandb
# Successfully installed GitPython-3.1.40 docker-pycreds-0.4.0 gitdb-4.0.11 pathtools-0.1.2 sentry-sdk-1.34.0 setproctitle-1.3.3 smmap-5.0.1 wandb-0.15.12

# %%
import os
import numpy as np
import seaborn as sns
import zipfile
import pandas as pd
import matplotlib.pyplot as plt
import cv2
from skimage import io
import torch
import random
import pandas as pd
import random
import glob
import sklearn as sk
from sklearn.preprocessing import StandardScaler, normalize
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn import metrics
from IPython.display import display
import torch
from torch import nn, optim
from torch.nn import Sequential
from torch.optim import Optimizer, Adam
from torch.utils.data import DataLoader, Dataset, Sampler
from torch.utils.data import SubsetRandomSampler, ConcatDataset
from torch.utils.data import random_split
from torchvision.io import read_image
from torchvision import transforms as t
from torchvision.transforms import functional as F
from torch.optim import lr_scheduler
import wandb
import IPython
import math

# %%
# !wandb login --relogin --host=http://wandb.your-shared-local-host.com

# %%
wandb.login(key='f63f6bf237335da137544dff247f145d2db7f47a')
# Out:
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %% [markdown]
# # read dataset and show classes

# %%
import pickle
def read_from_pickle(path):
  pfile = open(path, 'rb')
  return pd.read_pickle(pfile)

train_path = data_path + 'train.pickle'
val_path = data_path + 'validation.pickle'
test_path = data_path + 'test.pickle'

trainset = np.array(read_from_pickle(train_path))
valset = np.array(read_from_pickle(val_path))
testset = np.array(read_from_pickle(test_path))
# Out:
# <ipython-input-13-fb36756d86ac>:10: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   trainset = np.array(read_from_pickle(train_path))
# <ipython-input-13-fb36756d86ac>:11: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   valset = np.array(read_from_pickle(val_path))
# <ipython-input-13-fb36756d86ac>:12: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   testset = np.array(read_from_pickle(test_path))

# %%
classes = np.unique(trainset[:, 1])
classes
# Out:
# array([1, 2, 3], dtype=object)

# %%
def changeClassIndices(dataset):
  for i in range(len(dataset[:, 1])):
    if dataset[i, 1] == 1:
      dataset[i, 1] = 0
    elif dataset[i, 1] == 2:
      dataset[i, 1] = 1
    elif dataset[i, 1] == 3:
      dataset[i, 1] = 2

changeClassIndices(trainset)
changeClassIndices(valset)
changeClassIndices(testset)

# %%
testset.shape
# Out:
# (307, 2)

# %%
classes = np.unique(trainset[:, 1])
classes
# Out:
# array([0, 1, 2], dtype=object)

# %%
class_names =  ['Ⅿeningioⅿa', 'Gⅼioⅿa', 'Pitutary'] # 0 1 2

# %%
def showSamples(dataset, class_ = 0):
  indices = np.where(dataset[:,1] == class_)
  selected_samples = dataset[np.random.choice(indices[0], 3)]

  fig,axs = plt.subplots(1,3, figsize=(15,15))
  axs[0].title.set_text(class_names[class_] + ' 1')
  axs[0].imshow(selected_samples[0][0])
  axs[1].title.set_text(class_names[class_] + ' 2')
  axs[1].imshow(selected_samples[2][0], cmap='gray')
  axs[2].title.set_text(class_names[class_] + ' 3')
  axs[2].imshow(selected_samples[2][0])

showSamples(trainset, class_=0)
showSamples(trainset, class_=1)
showSamples(trainset, class_=2)

# %% [markdown]
# # Dataset

# %%
import torchvision
transform = t.Compose([
    torchvision.transforms.ToTensor(),
])

# %%
class DatasetPair(Dataset):
  def __init__(self, x, y, transform=transform, twoCropTransform=None):
    self.img_labels = y
    self.imgs = x
    self.transform = transform
    self.twoCropTransform = twoCropTransform

  def __len__(self):
    return len(self.img_labels)

  def __getitem__(self, idx):
    image = self.imgs[idx]
    label = self.img_labels[idx]

    if self.twoCropTransform:
      image = self.twoCropTransform(image)
    else:
      image = self.transform(image)
    return image, label

# %%
train_dataset = DatasetPair(trainset[:, 0], trainset[:, 1])
val_dataset = DatasetPair(valset[:, 0], valset[:, 1])
test_dataset = DatasetPair(testset[:, 0], testset[:, 1])

# %%
print('x_train.shape: ', train_dataset.imgs.shape)
print('x_val.shape: ', val_dataset.imgs.shape)
print('x_test.shape: ', test_dataset.imgs.shape)
print('y_train.shape: ', train_dataset.img_labels.shape)
# Out:
# x_train.shape:  (2451,)
# x_val.shape:  (306,)
# x_test.shape:  (307,)
# y_train.shape:  (2451,)

# %% [markdown]
# # Useful Functions
#   **Training and validating one epoch - Evaluate**

# %%
from sklearn import metrics

def train_one_epoch(model, loader, criterion, optimizer, history, device):
    model.train()
    running_loss = 0.0
    running_accuracy = 0.0

    for i, data in enumerate(loader):
        inputs, labels = data[0].to(device), data[1].to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

        _, preds = torch.max(outputs, 1)
        running_accuracy += metrics.accuracy_score(labels.cpu(), preds.cpu())

    loss = running_loss / len(loader)
    accuracy = running_accuracy / len(loader)

    history['acc'].append(accuracy)
    history['loss'].append(loss)
    return loss, accuracy

def validate_one_epoch(model, loader, criterion, history, device):
    model.eval()

    running_loss = 0.0
    running_accuracy = 0.0
    running_precision = 0.0
    running_recall = 0.0
    running_f1_score = 0.0
    with torch.no_grad():
        for data in loader:
            inputs, labels = data[0].to(device), data[1].to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            running_loss += loss.item()

            _, preds = torch.max(outputs, 1)
            running_loss += loss.item()
            running_accuracy += metrics.accuracy_score(labels.cpu(), preds.cpu())
            running_precision += metrics.precision_score(labels.cpu(), preds.cpu(), average='weighted', zero_division=0)
            running_recall += metrics.recall_score(labels.cpu(), preds.cpu(), average='weighted', zero_division=0)
            running_f1_score += metrics.f1_score(labels.cpu(), preds.cpu(), average='weighted', zero_division=0)

    loss = running_loss / len(loader)
    accuracy = running_accuracy / len(loader)
    precision = running_precision / len(loader)
    recall = running_recall / len(loader)
    f1_score = running_f1_score / len(loader)

    history['acc'].append(accuracy)
    history['loss'].append(loss)
    return loss, accuracy, precision, recall, f1_score

# %%
def showCharts(train_history, val_history, mode='acc'):
  epoch = np.arange(len(train_history['acc']))
  if mode == 'acc':
    plt.plot(epoch, train_history['acc'], label='train accuracy')
    plt.plot(epoch, val_history['acc'], label='validation accuracy')
    plt.ylabel('accuracy')
  elif mode == 'loss':
    plt.plot(epoch, train_history['loss'], label='train loss')
    plt.plot(epoch, val_history['loss'], label='validation loss')
    plt.ylabel('loss')

  plt.xlabel('epoch')
  plt.legend()

# %%
def evaluate(model, dataloader, criterion, device, history={'acc': [], 'loss': []}):
  loss, acc, precision, recall, f1 = validate_one_epoch(model, dataloader, criterion, history, device)

  print(f"Loss: {loss:.4f} - "
        f"ACC: {acc:.4f}% - "
        f"Precision: {precision:.4f}% - "
        f"Recall {recall:.4f}% - "
        f"F1 score: {f1:.2f}%")

# %%
def prediction(model, loader, device):
    model.eval()

    y_truth = []
    y_preds = []
    with torch.no_grad():
        for data in loader:
            inputs, labels = data[0].to(device), data[1].to(device)
            outputs = model(inputs)

            _, preds = torch.max(outputs, 1)
            y_preds.extend(preds.cpu())
            y_truth.extend(labels.cpu())

    return y_preds, y_truth

def confusionMatrix(model, dataloader, device):
  y_preds, y_truth = prediction(model, dataloader, device)

  cm = confusion_matrix(y_truth, y_preds, labels=[0, 1, 2])
  disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                display_labels=class_names)
  disp.plot()
  plt.show()

# %% [markdown]
# # AlexNet From Scratch

# %%
class AlexNet(nn.Module):
    def __init__(self, num_classes = 10):
        super(AlexNet, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=11, stride=4, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(64, 192, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(192, 384, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
        )
        self.avgpool = nn.AdaptiveAvgPool2d((6, 6))
        self.classifier = nn.Sequential(
            nn.Dropout(),
            nn.Linear(256 * 6 * 6, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(4096, 1024), # (4096, 4096) --> (4096, 1024) to avoid overfitting and heavy losses during training
            nn.ReLU(inplace=True),
            nn.Linear(1024, num_classes),
        )

    def forward(self, x):
      x = self.features(x)
      x = self.avgpool(x)
      x = x.view(-1, 256 * 6 * 6)
      x = self.classifier(x)
      return x

# %% [markdown]
# ## Train

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# create model
alexnet = AlexNet(num_classes = 3).to(device)

# %%
BATCH_SIZE = 32
lr = 1e-3

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(alexnet.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)

train_dataloader = DataLoader(
        train_dataset,
        shuffle=True,
        batch_size=BATCH_SIZE)

val_dataloader = DataLoader(
        val_dataset,
        shuffle=True,
        batch_size=BATCH_SIZE)

test_dataloader = DataLoader(
        test_dataset,
        shuffle=True,
        batch_size=BATCH_SIZE)

# %%
num_epochs = 50

wandb.init(
    # set the wandb project where this run will be logged
    project="Brain MRI Classification",

    # track hyperparameters and run metadata
    config={
    "learning_rate": lr,
    "architecture": "CNN",
    "dataset": "CIFAR-100",
    "epochs": num_epochs,
    },
    name='alexnet_from_scratch'
)


train_history = {'acc': [], 'loss': []}
val_history = {'acc': [], 'loss': []}

model_path = data_path[:-5] + 'alexnet.pt'
best_valid_acc = 0
for epoch in range(num_epochs):
    train_loss, train_acc = train_one_epoch(alexnet, train_dataloader, criterion, optimizer, train_history, device)
    val_loss, val_acc, precision, recall, f1 = validate_one_epoch(alexnet, val_dataloader, criterion, val_history, device)

    wandb.log({"train_loss": train_loss, "train_acc": train_acc, "val_loss": val_loss, "val_acc": val_acc})

    if val_acc > best_valid_acc:
        best_valid_acc = val_acc
        torch.save(alexnet, model_path)

    print(f"Epoch [{epoch+1}/{num_epochs}] - "
          f"Train Loss: {train_loss:.4f} - "
          f"Train ACC: {train_acc:.4f}% - "
          f"Validation Loss: {val_loss:.4f} - "
          f"Validation ACC: {val_acc:.4f}% - "
          f"Validation Precision: {precision:.4f}% - "
          f"Validation: Recall {recall:.4f}% - "
          f"Validation F1: {f1:.2f}%")

wandb.finish()
# Out:
# wandb: Currently logged in as: amirezzati. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231102_094559-5g4xc9em</code>
# Syncing run <strong><a href='https://wandb.ai/amirezzati/Brain%20MRI%20classification/runs/5g4xc9em' target="_blank">alexnet_from_scratch</a></strong> to <a href='https://wandb.ai/amirezzati/Brain%20MRI%20classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/amirezzati/Brain%20MRI%20classification' target="_blank">https://wandb.ai/amirezzati/Brain%20MRI%20classification</a>
#  View run at <a href='https://wandb.ai/amirezzati/Brain%20MRI%20classification/runs/5g4xc9em' target="_blank">https://wandb.ai/amirezzati/Brain%20MRI%20classification/runs/5g4xc9em</a>
# Epoch [1/50] - Train Loss: 1.0744 - Train ACC: 0.4806% - Validation Loss: 1.6294 - Validation ACC: 0.6340% - Validation Precision: 0.5443% - Validation: Recall 0.6340% - Validation F1: 0.55%
# Epoch [2/50] - Train Loss: 0.7449 - Train ACC: 0.6589% - Validation Loss: 1.3618 - Validation ACC: 0.6642% - Validation Precision: 0.6418% - Validation: Recall 0.6642% - Validation F1: 0.62%
# Epoch [3/50] - Train Loss: 0.6715 - Train ACC: 0.6818% - Validation Loss: 1.2472 - Validation ACC: 0.6781% - Validation Precision: 0.5986% - Validation: Recall 0.6781% - Validation F1: 0.61%
# Epoch [4/50] - Train Loss: 0.5592 - Train ACC: 0.7417% - Validation Loss: 1.0432 - Validation ACC: 0.7934% - Validation Precision: 0.8230% - Validation: Recall 0.7934% - Validation F1: 0.79%
# Epoch [5/50] - Train Loss: 0.4757 - Train ACC: 0.7867% - Validation Loss: 0.8608 - Validation ACC: 0.8128% - Validation Precision: 0.8333% - Validation: Recall 0.8128% - Validation F1: 0.81%
# Epoch [6/50] - Train Loss: 0.4244 - Train ACC: 0.8211% - Validation Loss: 0.8908 - Validation ACC: 0.7927% - Validation Precision: 0.8402% - Validation: Recall 0.7927% - Validation F1: 0.80%
# Epoch [7/50] - Train Loss: 0.4330 - Train ACC: 0.8173% - Validation Loss: 0.8233 - Validation ACC: 0.8403% - Validation Precision: 0.8676% - Validation: Recall 0.8403% - Validation F1: 0.84%
# Epoch [8/50] - Train Loss: 0.3727 - Train ACC: 0.8451% - Validation Loss: 0.6945 - Validation ACC: 0.8396% - Validation Precision: 0.8464% - Validation: Recall 0.8396% - Validation F1: 0.83%
# Epoch [9/50] - Train Loss: 0.3474 - Train ACC: 0.8554% - Validation Loss: 0.6513 - Validation ACC: 0.8608% - Validation Precision: 0.8725% - Validation: Recall 0.8608% - Validation F1: 0.86%
# Epoch [10/50] - Train Loss: 0.3331 - Train ACC: 0.8689% - Validation Loss: 0.7171 - Validation ACC: 0.8302% - Validation Precision: 0.8617% - Validation: Recall 0.8302% - Validation F1: 0.83%
# Epoch [11/50] - Train Loss: 0.3222 - Train ACC: 0.8677% - Validation Loss: 1.0418 - Validation ACC: 0.8122% - Validation Precision: 0.8346% - Validation: Recall 0.8122% - Validation F1: 0.82%
# Epoch [12/50] - Train Loss: 0.3084 - Train ACC: 0.8718% - Validation Loss: 0.6287 - Validation ACC: 0.8601% - Validation Precision: 0.8620% - Validation: Recall 0.8601% - Validation F1: 0.86%
# Epoch [13/50] - Train Loss: 0.2844 - Train ACC: 0.8823% - Validation Loss: 0.6465 - Validation ACC: 0.8472% - Validation Precision: 0.8759% - Validation: Recall 0.8472% - Validation F1: 0.85%
# Epoch [14/50] - Train Loss: 0.2600 - Train ACC: 0.8933% - Validation Loss: 0.5893 - Validation ACC: 0.8757% - Validation Precision: 0.9034% - Validation: Recall 0.8757% - Validation F1: 0.88%
# Epoch [15/50] - Train Loss: 0.2724 - Train ACC: 0.8784% - Validation Loss: 0.5105 - Validation ACC: 0.8951% - Validation Precision: 0.9162% - Validation: Recall 0.8951% - Validation F1: 0.90%
# Epoch [16/50] - Train Loss: 0.2858 - Train ACC: 0.8844% - Validation Loss: 0.6076 - Validation ACC: 0.8701% - Validation Precision: 0.8809% - Validation: Recall 0.8701% - Validation F1: 0.87%
# Epoch [17/50] - Train Loss: 0.2778 - Train ACC: 0.8769% - Validation Loss: 0.6290 - Validation ACC: 0.8622% - Validation Precision: 0.9032% - Validation: Recall 0.8622% - Validation F1: 0.87%
# Epoch [18/50] - Train Loss: 0.2565 - Train ACC: 0.8878% - Validation Loss: 0.5134 - Validation ACC: 0.8865% - Validation Precision: 0.9187% - Validation: Recall 0.8865% - Validation F1: 0.89%
# Epoch [19/50] - Train Loss: 0.2197 - Train ACC: 0.9056% - Validation Loss: 0.4752 - Validation ACC: 0.8913% - Validation Precision: 0.9169% - Validation: Recall 0.8913% - Validation F1: 0.89%
# Epoch [20/50] - Train Loss: 0.2218 - Train ACC: 0.9095% - Validation Loss: 0.5996 - Validation ACC: 0.8740% - Validation Precision: 0.8974% - Validation: Recall 0.8740% - Validation F1: 0.88%
# Epoch [21/50] - Train Loss: 0.2271 - Train ACC: 0.9102% - Validation Loss: 0.4946 - Validation ACC: 0.8889% - Validation Precision: 0.8950% - Validation: Recall 0.8889% - Validation F1: 0.89%
# Epoch [22/50] - Train Loss: 0.2372 - Train ACC: 0.9000% - Validation Loss: 0.5421 - Validation ACC: 0.8826% - Validation Precision: 0.8912% - Validation: Recall 0.8826% - Validation F1: 0.88%
# Epoch [23/50] - Train Loss: 0.1922 - Train ACC: 0.9199% - Validation Loss: 0.4964 - Validation ACC: 0.8802% - Validation Precision: 0.8894% - Validation: Recall 0.8802% - Validation F1: 0.88%
# Epoch [24/50] - Train Loss: 0.1812 - Train ACC: 0.9177% - Validation Loss: 0.4580 - Validation ACC: 0.9014% - Validation Precision: 0.9195% - Validation: Recall 0.9014% - Validation F1: 0.90%
# Epoch [25/50] - Train Loss: 0.1805 - Train ACC: 0.9252% - Validation Loss: 0.6456 - Validation ACC: 0.8552% - Validation Precision: 0.8732% - Validation: Recall 0.8552% - Validation F1: 0.86%
# Epoch [26/50] - Train Loss: 0.1942 - Train ACC: 0.9236% - Validation Loss: 0.4818 - Validation ACC: 0.9083% - Validation Precision: 0.9279% - Validation: Recall 0.9083% - Validation F1: 0.91%
# Epoch [27/50] - Train Loss: 0.1770 - Train ACC: 0.9255% - Validation Loss: 0.4627 - Validation ACC: 0.8938% - Validation Precision: 0.9211% - Validation: Recall 0.8938% - Validation F1: 0.90%
# Epoch [28/50] - Train Loss: 0.1449 - Train ACC: 0.9364% - Validation Loss: 0.4096 - Validation ACC: 0.9163% - Validation Precision: 0.9342% - Validation: Recall 0.9163% - Validation F1: 0.92%
# Epoch [29/50] - Train Loss: 0.1526 - Train ACC: 0.9380% - Validation Loss: 0.5705 - Validation ACC: 0.8826% - Validation Precision: 0.8993% - Validation: Recall 0.8826% - Validation F1: 0.88%
# Epoch [30/50] - Train Loss: 0.1487 - Train ACC: 0.9356% - Validation Loss: 0.5544 - Validation ACC: 0.8913% - Validation Precision: 0.9034% - Validation: Recall 0.8913% - Validation F1: 0.89%
# Epoch [31/50] - Train Loss: 0.2026 - Train ACC: 0.9183% - Validation Loss: 0.3724 - Validation ACC: 0.9226% - Validation Precision: 0.9293% - Validation: Recall 0.9226% - Validation F1: 0.92%
# Epoch [32/50] - Train Loss: 0.1295 - Train ACC: 0.9464% - Validation Loss: 0.4000 - Validation ACC: 0.9125% - Validation Precision: 0.9339% - Validation: Recall 0.9125% - Validation F1: 0.92%
# Epoch [33/50] - Train Loss: 0.1154 - Train ACC: 0.9474% - Validation Loss: 0.3714 - Validation ACC: 0.9194% - Validation Precision: 0.9279% - Validation: Recall 0.9194% - Validation F1: 0.92%
# Epoch [34/50] - Train Loss: 0.1100 - Train ACC: 0.9555% - Validation Loss: 0.3886 - Validation ACC: 0.9219% - Validation Precision: 0.9318% - Validation: Recall 0.9219% - Validation F1: 0.92%
# Epoch [35/50] - Train Loss: 0.1258 - Train ACC: 0.9468% - Validation Loss: 0.5052 - Validation ACC: 0.9101% - Validation Precision: 0.9156% - Validation: Recall 0.9101% - Validation F1: 0.91%
# Epoch [36/50] - Train Loss: 0.0884 - Train ACC: 0.9643% - Validation Loss: 0.4774 - Validation ACC: 0.9163% - Validation Precision: 0.9347% - Validation: Recall 0.9163% - Validation F1: 0.92%
# Epoch [37/50] - Train Loss: 0.1125 - Train ACC: 0.9575% - Validation Loss: 0.4211 - Validation ACC: 0.9163% - Validation Precision: 0.9198% - Validation: Recall 0.9163% - Validation F1: 0.91%
# Epoch [38/50] - Train Loss: 0.0869 - Train ACC: 0.9647% - Validation Loss: 0.4320 - Validation ACC: 0.9132% - Validation Precision: 0.9258% - Validation: Recall 0.9132% - Validation F1: 0.91%
# Epoch [39/50] - Train Loss: 0.1155 - Train ACC: 0.9543% - Validation Loss: 0.5943 - Validation ACC: 0.9076% - Validation Precision: 0.9152% - Validation: Recall 0.9076% - Validation F1: 0.91%
# Epoch [40/50] - Train Loss: 0.1019 - Train ACC: 0.9590% - Validation Loss: 0.4885 - Validation ACC: 0.9076% - Validation Precision: 0.9292% - Validation: Recall 0.9076% - Validation F1: 0.91%
# Epoch [41/50] - Train Loss: 0.0936 - Train ACC: 0.9675% - Validation Loss: 0.5033 - Validation ACC: 0.9215% - Validation Precision: 0.9416% - Validation: Recall 0.9215% - Validation F1: 0.92%
# Epoch [42/50] - Train Loss: 0.0924 - Train ACC: 0.9624% - Validation Loss: 0.3839 - Validation ACC: 0.9250% - Validation Precision: 0.9383% - Validation: Recall 0.9250% - Validation F1: 0.93%
# Epoch [43/50] - Train Loss: 0.0881 - Train ACC: 0.9700% - Validation Loss: 0.3877 - Validation ACC: 0.9233% - Validation Precision: 0.9340% - Validation: Recall 0.9233% - Validation F1: 0.92%
# Epoch [44/50] - Train Loss: 0.0686 - Train ACC: 0.9732% - Validation Loss: 0.4230 - Validation ACC: 0.9271% - Validation Precision: 0.9346% - Validation: Recall 0.9271% - Validation F1: 0.93%
# Epoch [45/50] - Train Loss: 0.0539 - Train ACC: 0.9752% - Validation Loss: 0.4965 - Validation ACC: 0.9219% - Validation Precision: 0.9308% - Validation: Recall 0.9219% - Validation F1: 0.92%
# Epoch [46/50] - Train Loss: 0.0520 - Train ACC: 0.9838% - Validation Loss: 0.3901 - Validation ACC: 0.9437% - Validation Precision: 0.9490% - Validation: Recall 0.9437% - Validation F1: 0.95%
# Epoch [47/50] - Train Loss: 0.0445 - Train ACC: 0.9834% - Validation Loss: 0.3656 - Validation ACC: 0.9469% - Validation Precision: 0.9510% - Validation: Recall 0.9469% - Validation F1: 0.95%
# Epoch [48/50] - Train Loss: 0.0514 - Train ACC: 0.9834% - Validation Loss: 0.4807 - Validation ACC: 0.9132% - Validation Precision: 0.9168% - Validation: Recall 0.9132% - Validation F1: 0.91%
# Epoch [49/50] - Train Loss: 0.0694 - Train ACC: 0.9742% - Validation Loss: 0.4833 - Validation ACC: 0.9264% - Validation Precision: 0.9377% - Validation: Recall 0.9264% - Validation F1: 0.93%
# Epoch [50/50] - Train Loss: 0.0440 - Train ACC: 0.9830% - Validation Loss: 0.5636 - Validation ACC: 0.9344% - Validation Precision: 0.9442% - Validation: Recall 0.9344% - Validation F1: 0.94%
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_acc</td><td>▁▃▄▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇█████████████</td></tr><tr><td>train_loss</td><td>█▆▅▄▄▄▃▃▃▃▃▂▃▃▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▂▂▅▅▆▆▆▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇█▇███▇█</td></tr><tr><td>val_loss</td><td>█▇▆▅▄▄▃▃▅▂▃▂▂▂▂▂▂▂▂▂▂▂▁▂▁▁▁▁▂▁▁▂▂▁▁▁▁▁▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_acc</td><td>0.98295</td></tr><tr><td>train_loss</td><td>0.04403</td></tr><tr><td>val_acc</td><td>0.93437</td></tr><tr><td>val_loss</td><td>0.56363</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">alexnet_from_scratch</strong> at: <a href='https://wandb.ai/amirezzati/Brain%20MRI%20classification/runs/5g4xc9em' target="_blank">https://wandb.ai/amirezzati/Brain%20MRI%20classification/runs/5g4xc9em</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231102_094559-5g4xc9em/logs</code>

# %%
showCharts(train_history, val_history, mode='acc')

# %%
IPython.display.HTML('<iframe src="https://api.wandb.ai/links/amirezzati/i1o13gab" style="border:none;height:512px;width:1024px">')
# Out:
# <iframe src="https://api.wandb.ai/links/amirezzati/i1o13gab" style="border:none;height:512px;width:1024px">

# %%
showCharts(train_history, val_history, mode='loss')

# %%
IPython.display.HTML('<iframe src="https://api.wandb.ai/links/amirezzati/xk994e11" style="border:none;height:512px;width:1024px">')
# Out:
# <iframe src="https://api.wandb.ai/links/amirezzati/xk994e11" style="border:none;height:512px;width:1024px">

# %% [markdown]
# ## evaluate the model

# %%
model_path = data_path[:-5] + 'alexnet.pt'
alexnet = torch.load(model_path)

# %% [markdown]
# **in Trainset**

# %%
evaluate(alexnet, train_dataloader, criterion, device)
confusionMatrix(alexnet, train_dataloader, device)
# Out:
# Loss: 0.0428 - ACC: 0.9959% - Precision: 0.9963% - Recall 0.9959% - F1 score: 1.00%

# %% [markdown]
# **in Validationset**

# %%
evaluate(alexnet, val_dataloader, criterion, device)
confusionMatrix(alexnet, val_dataloader, device)
# Out:
# Loss: 0.3671 - ACC: 0.9469% - Precision: 0.9553% - Recall 0.9469% - F1 score: 0.95%

# %% [markdown]
# **in Testset**

# %%
evaluate(alexnet, test_dataloader, criterion, device)
confusionMatrix(alexnet, test_dataloader, device)
# Out:
# Loss: 0.4179 - ACC: 0.9281% - Precision: 0.9324% - Recall 0.9281% - F1 score: 0.93%

# %% [markdown]
# # Pretrained AlexNet from torchvision

# %%
alexnet_t = torchvision.models.alexnet(pretrained=True)
alexnet_t.classifier[6] = nn.Linear(4096, 3)

# freeze all layer but classifier
unfreeze = ['classifier']
for layer_name, layer in alexnet_t.named_parameters():
    for name in unfreeze:
        if name in layer_name:
            layer.requires_grad = True
            break
        else:
            layer.requires_grad = False
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# create model
alexnet_t.to(device)
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=3, bias=True)
#   )
# )

# %%
BATCH_SIZE = 32
lr = 1e-3

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(filter(lambda p: p.requires_grad, alexnet_t.parameters()), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)

train_dataloader = DataLoader(
        train_dataset,
        shuffle=True,
        batch_size=BATCH_SIZE)

val_dataloader = DataLoader(
        val_dataset,
        shuffle=True,
        batch_size=BATCH_SIZE)

test_dataloader = DataLoader(
        test_dataset,
        shuffle=True,
        batch_size=BATCH_SIZE)

# %%
num_epochs = 20

wandb.init(
    # set the wandb project where this run will be logged
    project="Brain MRI Classification",

    # track hyperparameters and run metadata
    config={
    "learning_rate": lr,
    "architecture": "CNN",
    "dataset": "CIFAR-100",
    "epochs": num_epochs,
    },
    name='pretrained_alexnet'
)

train_history = {'acc': [], 'loss': []}
val_history = {'acc': [], 'loss': []}

model_path = data_path[:-5] + 'alexnet_t.pt'
best_valid_acc = 0
for epoch in range(num_epochs):
    train_loss, train_acc = train_one_epoch(alexnet_t, train_dataloader, criterion, optimizer, train_history, device)
    val_loss, val_acc, precision, recall, f1 = validate_one_epoch(alexnet_t, val_dataloader, criterion, val_history, device)

    wandb.log({"train_loss": train_loss, "train_acc": train_acc, "val_loss": val_loss, "val_acc": val_acc})

    if val_acc > best_valid_acc:
        best_valid_acc = val_acc
        torch.save(alexnet_t, model_path)

    print(f"Epoch [{epoch+1}/{num_epochs}] - "
          f"Train Loss: {train_loss:.4f} - "
          f"Train ACC: {train_acc:.4f}% - "
          f"Validation Loss: {val_loss:.4f} - "
          f"Validation ACC: {val_acc:.4f}% - "
          f"Validation Precision: {precision:.4f}% - "
          f"Validation: Recall {recall:.4f}% - "
          f"Validation F1: {f1:.2f}%")

wandb.finish()
# Out:
# wandb: Currently logged in as: amirezzati. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231101_200910-o5z868a9</code>
# Syncing run <strong><a href='https://wandb.ai/amirezzati/Brain%20MRI%20classification/runs/o5z868a9' target="_blank">pretrained_alexnet</a></strong> to <a href='https://wandb.ai/amirezzati/Brain%20MRI%20classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/amirezzati/Brain%20MRI%20classification' target="_blank">https://wandb.ai/amirezzati/Brain%20MRI%20classification</a>
#  View run at <a href='https://wandb.ai/amirezzati/Brain%20MRI%20classification/runs/o5z868a9' target="_blank">https://wandb.ai/amirezzati/Brain%20MRI%20classification/runs/o5z868a9</a>
# Epoch [1/20] - Train Loss: 0.5814 - Train ACC: 0.7575% - Validation Loss: 0.8116 - Validation ACC: 0.7910% - Validation Precision: 0.8119% - Validation: Recall 0.7910% - Validation F1: 0.75%
# Epoch [2/20] - Train Loss: 0.3296 - Train ACC: 0.8757% - Validation Loss: 0.6256 - Validation ACC: 0.8677% - Validation Precision: 0.8830% - Validation: Recall 0.8677% - Validation F1: 0.86%
# Epoch [3/20] - Train Loss: 0.2903 - Train ACC: 0.8850% - Validation Loss: 0.4245 - Validation ACC: 0.8969% - Validation Precision: 0.9136% - Validation: Recall 0.8969% - Validation F1: 0.90%
# Epoch [4/20] - Train Loss: 0.2631 - Train ACC: 0.8965% - Validation Loss: 0.6241 - Validation ACC: 0.8684% - Validation Precision: 0.9094% - Validation: Recall 0.8684% - Validation F1: 0.87%
# Epoch [5/20] - Train Loss: 0.2518 - Train ACC: 0.9004% - Validation Loss: 0.6890 - Validation ACC: 0.8576% - Validation Precision: 0.9025% - Validation: Recall 0.8576% - Validation F1: 0.86%
# Epoch [6/20] - Train Loss: 0.2189 - Train ACC: 0.9221% - Validation Loss: 0.3230 - Validation ACC: 0.9250% - Validation Precision: 0.9317% - Validation: Recall 0.9250% - Validation F1: 0.93%
# Epoch [7/20] - Train Loss: 0.2073 - Train ACC: 0.9275% - Validation Loss: 0.3344 - Validation ACC: 0.9288% - Validation Precision: 0.9352% - Validation: Recall 0.9288% - Validation F1: 0.93%
# Epoch [8/20] - Train Loss: 0.2067 - Train ACC: 0.9200% - Validation Loss: 0.4291 - Validation ACC: 0.8983% - Validation Precision: 0.9194% - Validation: Recall 0.8983% - Validation F1: 0.90%
# Epoch [9/20] - Train Loss: 0.1990 - Train ACC: 0.9221% - Validation Loss: 0.4536 - Validation ACC: 0.8920% - Validation Precision: 0.9118% - Validation: Recall 0.8920% - Validation F1: 0.88%
# Epoch [10/20] - Train Loss: 0.1511 - Train ACC: 0.9395% - Validation Loss: 0.3484 - Validation ACC: 0.9271% - Validation Precision: 0.9369% - Validation: Recall 0.9271% - Validation F1: 0.92%
# Epoch [11/20] - Train Loss: 0.1624 - Train ACC: 0.9329% - Validation Loss: 0.2934 - Validation ACC: 0.9313% - Validation Precision: 0.9443% - Validation: Recall 0.9313% - Validation F1: 0.93%
# Epoch [12/20] - Train Loss: 0.1573 - Train ACC: 0.9401% - Validation Loss: 0.3084 - Validation ACC: 0.9358% - Validation Precision: 0.9381% - Validation: Recall 0.9358% - Validation F1: 0.93%
# Epoch [13/20] - Train Loss: 0.1598 - Train ACC: 0.9444% - Validation Loss: 0.3554 - Validation ACC: 0.9288% - Validation Precision: 0.9407% - Validation: Recall 0.9288% - Validation F1: 0.93%
# Epoch [14/20] - Train Loss: 0.1484 - Train ACC: 0.9438% - Validation Loss: 0.3888 - Validation ACC: 0.9226% - Validation Precision: 0.9397% - Validation: Recall 0.9226% - Validation F1: 0.92%
# Epoch [15/20] - Train Loss: 0.1554 - Train ACC: 0.9416% - Validation Loss: 0.4661 - Validation ACC: 0.9233% - Validation Precision: 0.9305% - Validation: Recall 0.9233% - Validation F1: 0.92%
# Epoch [16/20] - Train Loss: 0.1508 - Train ACC: 0.9429% - Validation Loss: 0.3026 - Validation ACC: 0.9201% - Validation Precision: 0.9332% - Validation: Recall 0.9201% - Validation F1: 0.92%
# Epoch [17/20] - Train Loss: 0.1439 - Train ACC: 0.9482% - Validation Loss: 0.5460 - Validation ACC: 0.9052% - Validation Precision: 0.9169% - Validation: Recall 0.9052% - Validation F1: 0.90%
# Epoch [18/20] - Train Loss: 0.1322 - Train ACC: 0.9507% - Validation Loss: 0.3479 - Validation ACC: 0.9413% - Validation Precision: 0.9479% - Validation: Recall 0.9413% - Validation F1: 0.94%
# Epoch [19/20] - Train Loss: 0.1275 - Train ACC: 0.9563% - Validation Loss: 0.2899 - Validation ACC: 0.9444% - Validation Precision: 0.9511% - Validation: Recall 0.9444% - Validation F1: 0.94%
# Epoch [20/20] - Train Loss: 0.1091 - Train ACC: 0.9567% - Validation Loss: 0.2971 - Validation ACC: 0.9358% - Validation Precision: 0.9401% - Validation: Recall 0.9358% - Validation F1: 0.93%
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_acc</td><td>▁▅▅▆▆▇▇▇▇▇▇▇██▇█████</td></tr><tr><td>train_loss</td><td>█▄▄▃▃▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁</td></tr><tr><td>val_acc</td><td>▁▅▆▅▄▇▇▆▆▇▇█▇▇▇▇▆███</td></tr><tr><td>val_loss</td><td>█▆▃▅▆▁▂▃▃▂▁▁▂▂▃▁▄▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_acc</td><td>0.9567</td></tr><tr><td>train_loss</td><td>0.10912</td></tr><tr><td>val_acc</td><td>0.93576</td></tr><tr><td>val_loss</td><td>0.29714</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">pretrained_alexnet</strong> at: <a href='https://wandb.ai/amirezzati/Brain%20MRI%20classification/runs/o5z868a9' target="_blank">https://wandb.ai/amirezzati/Brain%20MRI%20classification/runs/o5z868a9</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231101_200910-o5z868a9/logs</code>

# %%
showCharts(train_history, val_history, mode='acc')

# %% [markdown]
# WandB chart

# %%
IPython.display.HTML('<iframe src="https://api.wandb.ai/links/amirezzati/ek2u2kxe" style="border:none;height:512px;width:1024px">')
# Out:
# <iframe src="https://api.wandb.ai/links/amirezzati/ek2u2kxe" style="border:none;height:512px;width:1024px">

# %%
showCharts(train_history, val_history, mode='loss')

# %% [markdown]
# WandB chart

# %%
IPython.display.HTML('<iframe src="https://api.wandb.ai/links/amirezzati/pvtxm8yo" style="border:none;height:512px;width:1024px">')
# Out:
# <iframe src="https://api.wandb.ai/links/amirezzati/pvtxm8yo" style="border:none;height:512px;width:1024px">

# %% [markdown]
# ## evaluate the model

# %%
model_path = data_path[:-5] + 'alexnet_t.pt'
alexnet_t = torch.load(model_path)

# %% [markdown]
# **in Trainset**

# %%
evaluate(alexnet_t, train_dataloader, criterion, device)
confusionMatrix(alexnet_t, train_dataloader, device)
# Out:
# Loss: 0.0593 - ACC: 0.9903% - Precision: 0.9909% - Recall 0.9903% - F1 score: 0.99%

# %% [markdown]
# **in Validationset**

# %%
evaluate(alexnet_t, val_dataloader, criterion, device)
confusionMatrix(alexnet_t, val_dataloader, device)
# Out:
# Loss: 0.3074 - ACC: 0.9444% - Precision: 0.9484% - Recall 0.9444% - F1 score: 0.94%

# %% [markdown]
# **in Testset**

# %%
evaluate(alexnet_t, test_dataloader, criterion, device)
confusionMatrix(alexnet_t, test_dataloader, device)
# Out:
# Loss: 0.4316 - ACC: 0.9344% - Precision: 0.9412% - Recall 0.9344% - F1 score: 0.93%

# %% [markdown]
# # AlexNet (10 epochs with supervised contrastive loss - 5 epochs with cross entropy)

# %% [markdown]
# ## modified train procedure and transform of dataset for this section

# %% [markdown]
# **Two crop Transform**

# %%
class TwoCropTransform:
    """Create two crops of the same image"""
    def __init__(self, transform):
        self.transform = transform

    def __call__(self, x):
        return [self.transform(x), self.transform(x)]

# %% [markdown]
# ## Supervised Contrastive loss

# %%
"""
Author: Yonglong Tian (yonglong@mit.edu)
Date: May 07, 2020
"""
from __future__ import print_function

import torch
import torch.nn as nn


class SupConLoss(nn.Module):
    """Supervised Contrastive Learning: https://arxiv.org/pdf/2004.11362.pdf."""
    def __init__(self, temperature=0.07, contrast_mode='all',
                 base_temperature=0.07):
        super(SupConLoss, self).__init__()
        self.temperature = temperature
        self.contrast_mode = contrast_mode
        self.base_temperature = base_temperature

    def forward(self, features, labels=None, mask=None):
        """Compute loss for model. If both `labels` and `mask` are None,
        it degenerates to SimCLR unsupervised loss:
        https://arxiv.org/pdf/2002.05709.pdf

        Args:
            features: hidden vector of shape [bsz, n_views, ...].
            labels: ground truth of shape [bsz].
            mask: contrastive mask of shape [bsz, bsz], mask_{i,j}=1 if sample j
                has the same class as sample i. Can be asymmetric.
        Returns:
            A loss scalar.
        """
        device = (torch.device('cuda')
                  if features.is_cuda
                  else torch.device('cpu'))

        if len(features.shape) < 3:
            raise ValueError('`features` needs to be [bsz, n_views, ...],'
                             'at least 3 dimensions are required')
        if len(features.shape) > 3:
            features = features.view(features.shape[0], features.shape[1], -1)

        batch_size = features.shape[0]
        if labels is not None and mask is not None:
            raise ValueError('Cannot define both `labels` and `mask`')
        elif labels is None and mask is None:
            mask = torch.eye(batch_size, dtype=torch.float32).to(device)
        elif labels is not None:
            labels = labels.contiguous().view(-1, 1)
            if labels.shape[0] != batch_size:
                raise ValueError('Num of labels does not match num of features')
            mask = torch.eq(labels, labels.T).float().to(device)
        else:
            mask = mask.float().to(device)

        contrast_count = features.shape[1]
        contrast_feature = torch.cat(torch.unbind(features, dim=1), dim=0)
        if self.contrast_mode == 'one':
            anchor_feature = features[:, 0]
            anchor_count = 1
        elif self.contrast_mode == 'all':
            anchor_feature = contrast_feature
            anchor_count = contrast_count
        else:
            raise ValueError('Unknown mode: {}'.format(self.contrast_mode))

        # compute logits
        anchor_dot_contrast = torch.div(
            torch.matmul(anchor_feature, contrast_feature.T),
            self.temperature)
        # for numerical stability
        logits_max, _ = torch.max(anchor_dot_contrast, dim=1, keepdim=True)
        logits = anchor_dot_contrast - logits_max.detach()

        # tile mask
        mask = mask.repeat(anchor_count, contrast_count)
        # mask-out self-contrast cases
        logits_mask = torch.scatter(
            torch.ones_like(mask),
            1,
            torch.arange(batch_size * anchor_count).view(-1, 1).to(device),
            0
        )
        mask = mask * logits_mask

        # compute log_prob
        exp_logits = torch.exp(logits) * logits_mask
        log_prob = logits - torch.log(exp_logits.sum(1, keepdim=True))

        # compute mean of log-likelihood over positive
        mean_log_prob_pos = (mask * log_prob).sum(1) / mask.sum(1)

        # loss
        loss = - (self.temperature / self.base_temperature) * mean_log_prob_pos
        loss = loss.view(anchor_count, batch_size).mean()

        return loss

# %% [markdown]
# ## Create Dataset

# %%
transform = t.Compose([
    torchvision.transforms.ToPILImage(),
    torchvision.transforms.RandomHorizontalFlip(),
    # torchvision.transforms.RandomGrayscale(p=0.2),
    torchvision.transforms.ToTensor(),
])

train_dataset_e = DatasetPair(trainset[:, 0], trainset[:, 1], twoCropTransform=TwoCropTransform(transform))
val_dataset_e = DatasetPair(valset[:, 0], valset[:, 1], twoCropTransform=TwoCropTransform(transform))
test_dataset_e = DatasetPair(testset[:, 0], testset[:, 1], twoCropTransform=TwoCropTransform(transform))

# %%
print('sample 0: ', type(train_dataset_e[0]))
print('sample 0 num of images: ', len(train_dataset_e[0][0]))
print('sample 0 shape of each image: ', train_dataset_e[0][0][0].shape)
# Out:
# sample 0:  <class 'tuple'>
# sample 0 num of images:  2
# sample 0 shape of each image:  torch.Size([3, 512, 512])

# %% [markdown]
# ## Encoder ( AlexNet )

# %%
class AlexNetEncoder(nn.Module):
    def __init__(self, feat_dim = 50):
        super(AlexNetEncoder, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=11, stride=4, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(64, 192, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(192, 384, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
        )
        self.avgpool = nn.AdaptiveAvgPool2d((6, 6))
        self.encoder = nn.Sequential(
            nn.Dropout(),
            nn.Linear(256 * 6 * 6, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(4096, 1024), # (4096, 4096) --> (4096, 1024) to avoid overfitting and heavy losses during training
            nn.ReLU(inplace=True),
            nn.Linear(1024, feat_dim),
        )

    def forward(self, x):
      x = self.features(x)
      x = self.avgpool(x)
      x = x.view(-1, 256 * 6 * 6)
      x = self.encoder(x)
      return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# create model
alexnet_encoder = AlexNetEncoder(feat_dim = 60).to(device)

# %%
BATCH_SIZE = 32
lr = 1e-4

optimizer = optim.Adam(alexnet_encoder.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)

train_dataloader = DataLoader(
        train_dataset_e,
        shuffle=True,
        batch_size=BATCH_SIZE)

val_dataloader = DataLoader(
        val_dataset_e,
        shuffle=True,
        batch_size=BATCH_SIZE)

test_dataloader = DataLoader(
        test_dataset_e,
        shuffle=True,
        batch_size=BATCH_SIZE)

# %%
def train_one_epoch_encoder(model, loader, criterion, optimizer, history, device):
    model.train()
    running_loss = 0.0

    for i, data in enumerate(loader):
        inputs, labels = data[0], data[1].to(device)

        inputs = torch.cat([inputs[0], inputs[1]], dim=0).to(device)

        optimizer.zero_grad()
        features = model(inputs)

        bsz = labels.shape[0]
        f1, f2 = torch.split(features, [bsz, bsz], dim=0)
        features = torch.cat([f1.unsqueeze(1), f2.unsqueeze(1)], dim=1)

        loss = criterion(features, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

    loss = running_loss / len(loader)

    history['loss'].append(loss)
    return loss

def validate_one_epoch_encoder(model, loader, criterion, history, device):
    model.eval()

    running_loss = 0.0
    with torch.no_grad():
        for data in loader:
            inputs, labels = data[0], data[1].to(device)
            inputs = torch.cat([inputs[0], inputs[1]], dim=0).to(device)

            features = model(inputs)

            bsz = labels.shape[0]
            f1, f2 = torch.split(features, [bsz, bsz], dim=0)
            features = torch.cat([f1.unsqueeze(1), f2.unsqueeze(1)], dim=1)

            loss = criterion(features, labels)
            running_loss += loss.item()

    loss = running_loss / len(loader)

    history['loss'].append(loss)
    return loss

# %%
def train_encoder(epochs, model, train_dataloader, val_dataloader, criterion, optimizer, train_history, val_history, model_path, device, best_valid_loss = math.inf):
  for epoch in range(epochs):
    train_loss = train_one_epoch_encoder(model, train_dataloader, criterion, optimizer, train_history, device)
    val_loss = validate_one_epoch_encoder(model, val_dataloader, criterion, val_history, device)

    wandb.log({"train_loss": train_loss, "val_loss": val_loss})

    if val_loss < best_valid_loss:
        best_valid_loss = val_loss
        torch.save(model, model_path)

    print(f"Epoch [{epoch+1}/{epochs}] - "
          f"Train Loss: {train_loss:.4f} - "
          f"Validation Loss: {val_loss:.4f} - ")
  return best_valid_loss

# %%
num_epochs = 15

wandb.init(
    # set the wandb project where this run will be logged
    project="Brain MRI Classification",

    # track hyperparameters and run metadata
    config={
    "learning_rate": lr,
    "architecture": "alexnet_encoder",
    "epochs": num_epochs,
    },
    name='alexnet_encoder'
)


train_history = {'loss': []}
val_history = {'loss': []}

model_path = data_path[:-5] + 'alexnet_encoder.pt'
best_valid_loss = math.inf

criterion = SupConLoss()
firt_best_loss = train_encoder(10, alexnet_encoder, train_dataloader, val_dataloader, criterion, optimizer, train_history, val_history, model_path, device, best_valid_loss = best_valid_loss)


wandb.finish()
# Out:
# Finishing last run (ID:zxp2zxko) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>█▁</td></tr><tr><td>val_loss</td><td>█▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>3.96205</td></tr><tr><td>val_loss</td><td>3.87524</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">alexnet_encoder</strong> at: <a href='https://wandb.ai/amirezzati/Brain%20MRI%20classification/runs/zxp2zxko' target="_blank">https://wandb.ai/amirezzati/Brain%20MRI%20classification/runs/zxp2zxko</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231104_190453-zxp2zxko/logs</code>
# Successfully finished last run (ID:zxp2zxko). Initializing new run:<br/>
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231104_190833-13266ft6</code>
# Syncing run <strong><a href='https://wandb.ai/amirezzati/Brain%20MRI%20classification/runs/13266ft6' target="_blank">alexnet_encoder</a></strong> to <a href='https://wandb.ai/amirezzati/Brain%20MRI%20classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/amirezzati/Brain%20MRI%20classification' target="_blank">https://wandb.ai/amirezzati/Brain%20MRI%20classification</a>
#  View run at <a href='https://wandb.ai/amirezzati/Brain%20MRI%20classification/runs/13266ft6' target="_blank">https://wandb.ai/amirezzati/Brain%20MRI%20classification/runs/13266ft6</a>
# Epoch [1/10] - Train Loss: 4.0165 - Validation Loss: 3.9030 -
# Epoch [2/10] - Train Loss: 3.9359 - Validation Loss: 3.8761 -
# Epoch [3/10] - Train Loss: 3.8608 - Validation Loss: 3.7649 -
# Epoch [4/10] - Train Loss: 3.8161 - Validation Loss: 3.7146 -
# Epoch [5/10] - Train Loss: 3.7672 - Validation Loss: 3.7007 -
# Epoch [6/10] - Train Loss: 3.7400 - Validation Loss: 3.6921 -
# Epoch [7/10] - Train Loss: 3.7092 - Validation Loss: 3.6959 -
# Epoch [8/10] - Train Loss: 3.6735 - Validation Loss: 3.6781 -
# Epoch [9/10] - Train Loss: 3.6551 - Validation Loss: 3.6500 -
# Epoch [10/10] - Train Loss: 3.6180 - Validation Loss: 3.5702 -
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>█▇▅▄▄▃▃▂▂▁</td></tr><tr><td>val_loss</td><td>█▇▅▄▄▄▄▃▃▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>3.61795</td></tr><tr><td>val_loss</td><td>3.57019</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">alexnet_encoder</strong> at: <a href='https://wandb.ai/amirezzati/Brain%20MRI%20classification/runs/13266ft6' target="_blank">https://wandb.ai/amirezzati/Brain%20MRI%20classification/runs/13266ft6</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231104_190833-13266ft6/logs</code>

# %%
IPython.display.HTML('<iframe src="https://api.wandb.ai/links/amirezzati/sj049iqy" style="border:none;height:512px;width:1024px">')
# Out:
# <iframe src="https://api.wandb.ai/links/amirezzati/sj049iqy" style="border:none;height:512px;width:1024px">

# %% [markdown]
# ## Classifier ( Linear )

# %%
class Classifier(nn.Module):
    def __init__(self, encoder, num_classes = 3):
        super(Classifier, self).__init__()
        self.encoder = encoder #torch.load(data_path[:-5] + 'alexnet_encoder.pt')

        # for layer_name, layer in self.encoder.named_parameters():
        #   layer.requires_grad = False

        self.classifier = nn.Sequential(
            nn.Linear(60, num_classes),
        )

    def forward(self, x):
      x = self.encoder(x)
      x = self.classifier(x)
      return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# create model
alexnet_classifier = Classifier(alexnet_encoder, num_classes = 3).to(device)

# %%
alexnet_classifier
# Out:
# Classifier(
#   (encoder): AlexNetEncoder(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#       (1): ReLU(inplace=True)
#       (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (4): ReLU(inplace=True)
#       (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (7): ReLU(inplace=True)
#       (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (9): ReLU(inplace=True)
#       (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (11): ReLU(inplace=True)
#       (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#     (encoder): Sequential(
#       (0): Dropout(p=0.5, inplace=False)
#       (1): Linear(in_features=9216, out_features=4096, bias=True)
#       (2): ReLU(inplace=True)
#       (3): Dropout(p=0.5, inplace=False)
#       (4): Linear(in_features=4096, out_features=1024, bias=True)
#       (5): ReLU(inplace=True)
#       (6): Linear(in_features=1024, out_features=60, bias=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=60, out_features=3, bias=True)
#   )
# )

# %% [markdown]
# **Learnable parameters**

# %%
# for layer_name, layer in alexnet_classifier.named_parameters():
#   if layer.requires_grad:
#     print(layer_name)

# %%
BATCH_SIZE = 32
lr = 1e-4

optimizer = optim.Adam(alexnet_encoder.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)

train_dataloader = DataLoader(
        train_dataset,
        shuffle=True,
        batch_size=BATCH_SIZE)

val_dataloader = DataLoader(
        val_dataset,
        shuffle=True,
        batch_size=BATCH_SIZE)

test_dataloader = DataLoader(
        test_dataset,
        shuffle=True,
        batch_size=BATCH_SIZE)

# %%
def train_classifier(epochs, model, train_dataloader, val_dataloader, criterion, optimizer, train_history, val_history, model_path, device, best_valid_acc = 0):
  for epoch in range(epochs):
    train_loss, train_acc = train_one_epoch(model, train_dataloader, criterion, optimizer, train_history, device)
    val_loss, val_acc, precision, recall, f1 = validate_one_epoch(model, val_dataloader, criterion, val_history, device)

    wandb.log({"train_loss": train_loss, "train_acc": train_acc, "val_loss": val_loss, "val_acc": val_acc})

    if val_acc > best_valid_acc:
        best_valid_acc = val_acc
        torch.save(model, model_path)

    print(f"Epoch [{epoch+1}/{epochs}] - "
          f"Train Loss: {train_loss:.4f} - "
          f"Train ACC: {train_acc:.4f}% - "
          f"Validation Loss: {val_loss:.4f} - "
          f"Validation ACC: {val_acc:.4f}% - "
          f"Validation Precision: {precision:.4f}% - "
          f"Validation: Recall {recall:.4f}% - "
          f"Validation F1: {f1:.2f}%")
  return best_valid_acc

# %%
num_epochs = 15

wandb.init(
    # set the wandb project where this run will be logged
    project="Brain MRI Classification",

    # track hyperparameters and run metadata
    config={
    "learning_rate": lr,
    "architecture": "alexnet_classifier",
    "epochs": num_epochs,
    },
    name='alexnet_classifier'
)


train_history = {'acc': [], 'loss': []}
val_history = {'acc': [], 'loss': []}

model_path = data_path[:-5] + 'alexnet_classifier.pt'
best_valid_acc = 0

criterion = nn.CrossEntropyLoss()
best_loss = train_classifier(5, alexnet_classifier, train_dataloader, val_dataloader, criterion, optimizer, train_history, val_history, model_path, device, best_valid_acc = best_valid_acc)


wandb.finish()
# Out:
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231104_192832-91wn80jx</code>
# Syncing run <strong><a href='https://wandb.ai/amirezzati/Brain%20MRI%20classification/runs/91wn80jx' target="_blank">alexnet_classifier</a></strong> to <a href='https://wandb.ai/amirezzati/Brain%20MRI%20classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/amirezzati/Brain%20MRI%20classification' target="_blank">https://wandb.ai/amirezzati/Brain%20MRI%20classification</a>
#  View run at <a href='https://wandb.ai/amirezzati/Brain%20MRI%20classification/runs/91wn80jx' target="_blank">https://wandb.ai/amirezzati/Brain%20MRI%20classification/runs/91wn80jx</a>
# Epoch [1/5] - Train Loss: 0.3375 - Train ACC: 0.8536% - Validation Loss: 0.6200 - Validation ACC: 0.8677% - Validation Precision: 0.8711% - Validation: Recall 0.8677% - Validation F1: 0.86%
# Epoch [2/5] - Train Loss: 0.2385 - Train ACC: 0.9010% - Validation Loss: 0.7959 - Validation ACC: 0.8503% - Validation Precision: 0.8954% - Validation: Recall 0.8503% - Validation F1: 0.85%
# Epoch [3/5] - Train Loss: 0.2280 - Train ACC: 0.9037% - Validation Loss: 0.7333 - Validation ACC: 0.8451% - Validation Precision: 0.8919% - Validation: Recall 0.8451% - Validation F1: 0.85%
# Epoch [4/5] - Train Loss: 0.2197 - Train ACC: 0.9145% - Validation Loss: 0.4302 - Validation ACC: 0.9052% - Validation Precision: 0.9121% - Validation: Recall 0.9052% - Validation F1: 0.90%
# Epoch [5/5] - Train Loss: 0.1861 - Train ACC: 0.9208% - Validation Loss: 0.4599 - Validation ACC: 0.9115% - Validation Precision: 0.9043% - Validation: Recall 0.9115% - Validation F1: 0.90%
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_acc</td><td>▁▆▆▇█</td></tr><tr><td>train_loss</td><td>█▃▃▃▁</td></tr><tr><td>val_acc</td><td>▃▂▁▇█</td></tr><tr><td>val_loss</td><td>▅█▇▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_acc</td><td>0.92084</td></tr><tr><td>train_loss</td><td>0.18606</td></tr><tr><td>val_acc</td><td>0.91146</td></tr><tr><td>val_loss</td><td>0.4599</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">alexnet_classifier</strong> at: <a href='https://wandb.ai/amirezzati/Brain%20MRI%20classification/runs/91wn80jx' target="_blank">https://wandb.ai/amirezzati/Brain%20MRI%20classification/runs/91wn80jx</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231104_192832-91wn80jx/logs</code>

# %%
IPython.display.HTML('<iframe src="https://api.wandb.ai/links/amirezzati/ln9ii8fa" style="border:none;height:512px;width:1024px">')
# Out:
# <iframe src="https://api.wandb.ai/links/amirezzati/ln9ii8fa" style="border:none;height:512px;width:1024px">

# %%
IPython.display.HTML('<iframe src="https://api.wandb.ai/links/amirezzati/adjsfvhd" style="border:none;height:512px;width:1024px">')
# Out:
# <iframe src="https://api.wandb.ai/links/amirezzati/adjsfvhd" style="border:none;height:512px;width:1024px">
